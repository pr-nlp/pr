# %%
# !pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached regex-2026.4.4-cp311-cp311-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Using cached regex-2026.4.4-cp311-cp311-win_amd64.whl (278 kB)
# ...
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# ...
#
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
# ...

# %%
# Install NLTK first (Run only once)
# pip install nltk

import nltk
from nltk.tokenize import WhitespaceTokenizer
from nltk.tokenize import wordpunct_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import MWETokenizer

from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer

from nltk.stem import WordNetLemmatizer

# Download required datasets (Run only once)
nltk.download('wordnet')
nltk.download('omw-1.4')

# Sample text
text = "Hello! I am learning NLP using NLTK. Let's learn tokenization :) #AI"

print("Original Text:")
print(text)

# ---------------------------------------------------
# 1. Whitespace Tokenization
# ---------------------------------------------------
ws_tokenizer = WhitespaceTokenizer()
print("\nWhitespace Tokenization:")
print(ws_tokenizer.tokenize(text))

# ---------------------------------------------------
# 2. Punctuation-based Tokenization
# ---------------------------------------------------
print("\nPunctuation-based Tokenization:")
print(wordpunct_tokenize(text))

# ---------------------------------------------------
# 3. Treebank Tokenization
# ---------------------------------------------------
treebank = TreebankWordTokenizer()
print("\nTreebank Tokenization:")
print(treebank.tokenize(text))

# ---------------------------------------------------
# 4. Tweet Tokenization
# ---------------------------------------------------
tweet_tokenizer = TweetTokenizer()
print("\nTweet Tokenization:")
print(tweet_tokenizer.tokenize(text))

# ---------------------------------------------------
# 5. MWE (Multi Word Expression) Tokenization
# ---------------------------------------------------
mwe_tokenizer = MWETokenizer([('New', 'York')], separator='_')

sentence = "I live in New York city"
tokens = sentence.split()

print("\nMWE Tokenization:")
print(mwe_tokenizer.tokenize(tokens))

# ---------------------------------------------------
# Stemming
# ---------------------------------------------------

words = ["running", "playing", "studies", "easily"]

# Porter Stemmer
porter = PorterStemmer()

print("\nPorter Stemming:")
for word in words:
    print(word, "->", porter.stem(word))

# Snowball Stemmer
snowball = SnowballStemmer("english")

print("\nSnowball Stemming:")
for word in words:
    print(word, "->", snowball.stem(word))

# ---------------------------------------------------
# Lemmatization
# ---------------------------------------------------

lemmatizer = WordNetLemmatizer()

print("\nLemmatization:")
for word in words:
    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Shri\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Shri\AppData\Roaming\nltk_data...
# Original Text:
# Hello! I am learning NLP using NLTK. Let's learn tokenization :) #AI
#
# Whitespace Tokenization:
# ['Hello!', 'I', 'am', 'learning', 'NLP', 'using', 'NLTK.', "Let's", 'learn', 'tokenization', ':)', '#AI']
#
# Punctuation-based Tokenization:
# ['Hello', '!', 'I', 'am', 'learning', 'NLP', 'using', 'NLTK', '.', 'Let', "'", 's', 'learn', 'tokenization', ':)', '#', 'AI']
#
# Treebank Tokenization:
# ['Hello', '!', 'I', 'am', 'learning', 'NLP', 'using', 'NLTK.', 'Let', "'s", 'learn', 'tokenization', ':', ')', '#', 'AI']
#
# Tweet Tokenization:
# ['Hello', '!', 'I', 'am', 'learning', 'NLP', 'using', 'NLTK', '.', "Let's", 'learn', 'tokenization', ':)', '#AI']
#
# MWE Tokenization:
# ['I', 'live', 'in', 'New_York', 'city']
#
# Porter Stemming:
# running -> run
# ...
